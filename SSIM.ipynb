# %%
from skimage.metrics import structural_similarity

# %%
from util.metrics import ssim

# %%
from pathlib import Path

# %%
data_path = Path('../../../mnt/wamri/WAMRI-LevensonLab/datasets/muse2he_urothelial_carcinoma')

# %%
from PIL import Image

# %%
import glob
images_A = glob.glob(str(data_path/'trainA/*'))
images_B = glob.glob(str(data_path/'trainB/*'))

# %%
import numpy as np
import torch
img1 = np.array(Image.open(images_A[0]))
img2 = np.array(Image.open(images_B[0]))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
torch.Tensor(img1).permute(2,0,1).unsqueeze(0).shape
# Out:
# torch.Size([1, 3, 512, 512])

# %%
structural_similarity(img1, img2,multichannel=True,win_size=11, gaussian_weights=True, sigma=1.5, use_sample_covariance=False, data_range=255.)
# Out:
# 0.2759028311029968

# %%
ssim(torch.Tensor(img1).permute(2,0,1).unsqueeze(0),torch.Tensor(img2).permute(2,0,1).unsqueeze(0),window_size=11,size_average=True)
# Out:
# tensor(0.2759)

# %%
torch.Tensor(img1).unsqueeze(0).shape
# Out:
# torch.Size([1, 512, 512, 3])
